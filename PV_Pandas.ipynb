# %%
import pandas as pd

pocty = [50, 27, 32]
pd_pocty = pd.Series(pocty)
print(pd_pocty)

pd_pocty = pd.Series(pocty, index = ["prumerny vek reditelu/ek", "prumerna vek sekretaru/ek", "prumerna vek zivnostniku"])
pd_pocty
# Out:
# 0    50
# 1    27
# 2    32
# dtype: int64
# prumerny vek reditelu/ek     50
# prumerna vek sekretaru/ek    27
# prumerna vek zivnostniku     32
# dtype: int64

# %%
zamestnanci = {
  "plat": [42000, 48400, 32500],
  "vek": [50, 40, 45]
}

df = pd.DataFrame(zamestnanci)
df
# Out:
#     plat  vek
# 0  42000   50
# 1  48400   40
# 2  32500   45

# %%
vysky = pd.Series({"Snezka": 1603, "Praded": 1491, "Plechy": 1378})

vysky_v_kilometrech = vysky / 1000
vysky_v_kilometrech
# Out:
# Snezka    1.603
# Praded    1.491
# Plechy    1.378
# dtype: float64

# %%
vysky[vysky > 1400]
# Out:
# Snezka    1603
# Praded    1491
# dtype: int64

# %%
vysky["Snezka"]
# Out:
# 1603

# %%
data = {
"pohori": ["Krkonose", "Jeseniky", "Sumava"],
"hora": ["Snezka", "Praded", "Plechy"],
"vyska": [1603, 1491, 1378],
"zeme": ["ČR", "ČR", "ČR"]
}
df = pd.DataFrame(data, columns = ["pohori", "hora", "vyska"])
df
# Out:
#      pohori    hora  vyska
# 0  Krkonose  Snezka   1603
# 1  Jeseniky  Praded   1491
# 2    Sumava  Plechy   1378

# %%
df['vyska']
# Out:
# 0    1603
# 1    1491
# 2    1378
# Name: vyska, dtype: int64

# %%
df[['hora', 'vyska']]
# Out:
#      hora  vyska
# 0  Snezka   1603
# 1  Praded   1491
# 2  Plechy   1378

# %%
df.loc[0]
df.loc[1]
# Out:
# pohori    Jeseniky
# hora        Praded
# vyska         1491
# Name: 1, dtype: object

# %% [markdown]
# Serazeni podle vysky

# %%
df = pd.DataFrame(data, columns = ["pohori", "hora", "vyska"])
df.sort_values('vyska')
# Out:
#      pohori    hora  vyska
# 2    Sumava  Plechy   1378
# 1  Jeseniky  Praded   1491
# 0  Krkonose  Snezka   1603

# %% [markdown]
# Vypis hor v Jesenikach

# %%
df = pd.DataFrame(data, columns = ["pohori", "hora"])
df.loc[1]
# Out:
# pohori    Jeseniky
# hora        Praded
# Name: 1, dtype: object

# %% [markdown]
# Prumerna vyska hor

# %%
df['vyska'].mean()
# Out:
# 1490.6666666666667

# %% [markdown]
# Nejmensi hora

# %%
df = pd.DataFrame(data, columns = ["hora", "vyska"])
df.nsmallest(1, 'vyska')
# Out:
#      hora  vyska
# 2  Plechy   1378

# %%
harrypotter_filename = 'https://raw.githubusercontent.com/adamerose/datasets/master/harry_potter_characters.csv'
hp_data = pd.read_csv(harrypotter_filename, sep=',', usecols=['Name'])
hp_data.head(5)
# Out:
#                                       Name
# 0                       Harry James Potter
# 1                    Ronald Bilius Weasley
# 2                    Hermione Jean Granger
# 3  Albus Percival Wulfric Brian Dumbledore
# 4                            Rubeus Hagrid

# %% [markdown]
# Prazdne bunky

# %%
hp_data = pd.read_csv(harrypotter_filename, sep=',')
hp_data = hp_data.isnull().sum()
hp_data
# Out:
# Id               0
# Name             0
# Gender           1
# Job             19
# House           39
# Wand             8
# Patronus        17
# Species          0
# Blood status    17
# Hair colour     17
# Eye colour      54
# Loyalty         51
# Skills          27
# Birth           13
# Death           98
# dtype: int64

# %% [markdown]
# **Vypis spatne formatovanych dat**

# %%
nehody_ciklistu_filename = 'https://raw.githubusercontent.com/mlcollege/ai-academy/main/05-Zaklady-datove-analyzy/data/nehody_cyklistu.csv'

bad_lines = []

def bad_line_capture(bad_line):
    global line_counter
    bad_lines.append((len(bad_lines) + 1, bad_line))
    return None


nc_data = pd.read_csv(nehody_ciklistu_filename, on_bad_lines = bad_line_capture, engine = 'python')

for line_num, line in bad_lines:
  print(f"Row {line_num}: {line}")
# Out:
# Row 0: ['2013/06/18 00:00:00+00;srážka s vozidlem zaparkovaným', ' odstaveným;řidičem nemotorového vozidla;Ano', ' obsah alkoholu v krvi od 0', '24‰ do 0', '5‰;lehké zranění;ano;žena']
# Row 1: ['2016/03/05 00:00:00+00;srážka s vozidlem zaparkovaným', ' odstaveným;řidičem nemotorového vozidla;Ano', ' obsah alkoholu v krvi od 1', '0‰ do 1', '5‰;bez zraněn;ne;muž']
# Row 2: ['2012/07/28 00:00:00+00;srážka s vozidlem zaparkovaným', ' odstaveným;řidičem nemotorového vozidla;Ano', ' obsah alkoholu v krvi od 0', '5‰ do 0', '8‰;lehké zranění;ne;muž']
# Row 3: ['2014/05/21 00:00:00+00;srážka s vozidlem zaparkovaným', ' odstaveným;řidičem nemotorového vozidla;Ano', ' obsah alkoholu v krvi od 0', '8‰ do 1', '0‰;lehké zranění;ne;muž']
# Row 4: ['2017/11/02 00:00:00+00;srážka s vozidlem zaparkovaným', ' odstaveným;řidičem nemotorového vozidla;Ano', ' obsah alkoholu v krvi od 1', '0‰ do 1', '5‰;lehké zranění;ne;žena']
# ...

# %% [markdown]
# **Vypis spatnych values**

# %%
nc_data = pd.read_csv(nehody_ciklistu_filename, sep=';')

genders = ["muž", "žena", "chlapec (do 15 let)", "dívka (do 15 let)"]

bad_rows = nc_data[~nc_data['pohlavi'].isin(genders)]

bad_rows
# Out:
# Empty DataFrame
# Columns: [datum, srazka, zavineni, alkohol, nasledek, prilba, pohlavi]
# Index: []

# %% [markdown]
# **Vypis duplicitnich radku**

# %%
nc_data = pd.read_csv(nehody_ciklistu_filename, sep=';')

nc_data[nc_data.duplicated()]
# Out:
#                        datum                                      srazka  \
# 236   2018/05/19 00:00:00+00                            jiný druh nehody
# 238   2018/05/19 00:00:00+00                            jiný druh nehody
# 239   2018/05/19 00:00:00+00                            jiný druh nehody
# 241   2018/05/19 00:00:00+00                            jiný druh nehody
# 242   2018/05/19 00:00:00+00                            jiný druh nehody
# 243   2018/05/19 00:00:00+00                            jiný druh nehody
# 244   2018/05/19 00:00:00+00                            jiný druh nehody
# 245   2018/05/19 00:00:00+00                            jiný druh nehody
# 246   2018/05/19 00:00:00+00                            jiný druh nehody
# 247   2018/05/19 00:00:00+00                            jiný druh nehody
# 263   2019/08/25 00:00:00+00      srážka s jedoucím nekolejovým vozidlem
# 339   2018/06/29 00:00:00+00      srážka s jedoucím nekolejovým vozidlem
# ...

# %% [markdown]
# **Smazani vsech radku s NaN value**

# %%
clear_hp = hp_data.dropna()
clear_hp
# Out:
#     Id                                     Name  Gender  \
# 3    4  Albus Percival Wulfric Brian Dumbledore    Male
# 6    7                             Fred Weasley    Male
# 14  15                         Remus John Lupin    Male
# 24  25                           Lavender Brown  Female
# 80  81                         Nymphadora Tonks  Female
#
#                                             Job       House  \
# 3                                    Headmaster  Gryffindor
# 6                                       Student  Gryffindor
# 14  Professor of Defence Against the Dark Arts   Gryffindor
# 24                                      Student  Gryffindor
# 80                                        Auror  Hufflepuff
#
#                                  Wand           Patronus   Species  \
# 3   15" Elder Thestral tail hair core            Phoenix     Human
# 6                             Unknown            Unknown     Human
# ...

# %% [markdown]
# **Permanentni smazani vsech NaN values**

# %%
hp_data.dropna(inplace=True)
hp_data
# Out:
#     Id                                     Name  Gender  \
# 3    4  Albus Percival Wulfric Brian Dumbledore    Male
# 6    7                             Fred Weasley    Male
# 14  15                         Remus John Lupin    Male
# 24  25                           Lavender Brown  Female
# 80  81                         Nymphadora Tonks  Female
#
#                                             Job       House  \
# 3                                    Headmaster  Gryffindor
# 6                                       Student  Gryffindor
# 14  Professor of Defence Against the Dark Arts   Gryffindor
# 24                                      Student  Gryffindor
# 80                                        Auror  Hufflepuff
#
#                                  Wand           Patronus   Species  \
# 3   15" Elder Thestral tail hair core            Phoenix     Human
# 6                             Unknown            Unknown     Human
# ...

# %%
hp_data = pd.read_csv(harrypotter_filename, sep=',')
hp_data
# Out:
#       Id                                     Name  Gender  \
# 0      1                       Harry James Potter    Male
# 1      2                    Ronald Bilius Weasley    Male
# 2      3                    Hermione Jean Granger  Female
# 3      4  Albus Percival Wulfric Brian Dumbledore    Male
# 4      5                            Rubeus Hagrid    Male
# ..   ...                                      ...     ...
# 135  136                 Wilhelmina Grubbly-Plank  Female
# 136  137                          Fenrir Greyback    Male
# 137  138                      Gellert Grindelwald    Male
# 138  139                                    Dobby    Male
# 139  140                                 Kreacher    Male
#
#                                                    Job       House  \
# 0                                              Student  Gryffindor
# 1                                              Student  Gryffindor
# ...

# %% [markdown]
# **Convert invalidnich datumu na datetime**

# %%
novy_sloupec_s_datumy = pd.to_datetime(nc_data['datum'])
novy_sloupec_s_datumy


nc_data['datum'] = novy_sloupec_s_datumy
nc_data
# Out:
#                          datum                                      srazka  \
# 0    2013-10-16 00:00:00+00:00      srážka s jedoucím nekolejovým vozidlem
# 1    2014-06-14 00:00:00+00:00                            srážka s chodcem
# 2    2014-08-13 00:00:00+00:00                                     havárie
# 3    2014-08-29 00:00:00+00:00                                     havárie
# 4    2015-02-02 00:00:00+00:00  srážka s vozidlem zaparkovaným, odstaveným
# ...                        ...                                         ...
# 1165 2019-09-05 00:00:00+00:00      srážka s jedoucím nekolejovým vozidlem
# 1166 2020-05-30 00:00:00+00:00                                     havárie
# 1167 2020-06-02 00:00:00+00:00                            srážka s chodcem
# 1168 2020-08-02 00:00:00+00:00                                     havárie
# 1169 2020-08-12 00:00:00+00:00                                     havárie
#
#                           zavineni  \
# ...

# %% [markdown]
# **Pouziti loc[]** (vyhodi error, v tomto csv nejsou zadne integers na tuto specifickou kontrolu, je to jen priklad)

# %%
for x in nc_data.index:
    if nc_data.loc[x, "ciselna_hodnota_do_1"] < 1:
       nc_data.loc[x, "ciselna_hodnota_do_1"] = 1
nc_data
# Out:
#                          datum                                      srazka  \
# 0    2013-10-16 00:00:00+00:00      srážka s jedoucím nekolejovým vozidlem
# 1    2014-06-14 00:00:00+00:00                            srážka s chodcem
# 2    2014-08-13 00:00:00+00:00                                     havárie
# 3    2014-08-29 00:00:00+00:00                                     havárie
# 4    2015-02-02 00:00:00+00:00  srážka s vozidlem zaparkovaným, odstaveným
# ...                        ...                                         ...
# 1165 2019-09-05 00:00:00+00:00      srážka s jedoucím nekolejovým vozidlem
# 1166 2020-05-30 00:00:00+00:00                                     havárie
# 1167 2020-06-02 00:00:00+00:00                            srážka s chodcem
# 1168 2020-08-02 00:00:00+00:00                                     havárie
# 1169 2020-08-12 00:00:00+00:00                                     havárie
#
#                           zavineni  \
# ...

# %% [markdown]
# **Odstraneni duplicit**

# %%
nc_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1165    False
# 1166    False
# 1167    False
# 1168    False
# 1169     True
# Length: 1170, dtype: bool
